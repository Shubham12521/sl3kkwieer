# %% [markdown]
# #  SL1_Assignment_1
# ### Data Wrangling, I
#
#
#
#
#
#
# ### 1. Import all the required Python Libraries.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 2. Locate open source data from the web (e.g., https://www.kaggle.com).
# #### URL of the web site:- https://www.kaggle.com/datasets/joebeachcapital/covid-19-india-statewise-2023
#
#
#
# ### 3. Load the Dataset into pandas dataframe.

# %%
ab = pd.read_csv("Latest Covid-19 India Status.csv")
ab
# Out:
#                                    State/UTs  Total Cases  Active  Discharged
# 0                        Andaman and Nicobar        10766       0       10637  \
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
ab.head()
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio
# 0  Andaman and Nicobar        10766       0       10637     129           0.0  \
# 1       Andhra Pradesh      2340676       0     2325943   14733           0.0
# 2    Arunachal Pradesh        67049       0       66753     296           0.0
# 3                Assam       746159       5      738119    8035           0.0
# 4                Bihar       855267       1      842952   12314           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 0            98.80         1.20   100896618
# 1            99.37         0.63   128500364
# 2            99.56         0.44      658019
# 3            98.92         1.08      290492
# 4            98.56         1.44    40100376

# %% [markdown]
# ### 4. Data Preprocessing:
#     a) describe() function to get some initial statistics

# %%
ab.describe()
# Out:
#         Total Cases       Active    Discharged         Deaths  Active Ratio
# count  3.600000e+01    36.000000  3.600000e+01      36.000000     36.000000  \
# mean   1.249975e+06    50.333333  1.235146e+06   14778.527778      0.005000
# std    1.846038e+06   207.118048  1.820328e+06   27221.140636      0.026673
# min    1.076600e+04     0.000000  1.063700e+04       4.000000      0.000000
# 25%    1.065430e+05     0.000000  1.055395e+05    1124.250000      0.000000
# 50%    6.140910e+05     1.500000  6.076750e+05    6551.000000      0.000000
# 75%    1.331951e+06     9.000000  1.322329e+06   14325.750000      0.000000
# max    8.171048e+06  1233.000000  8.022276e+06  148558.000000      0.160000
#
#        Discharge Ratio  Death Ratio    Population
# count        36.000000    36.000000  3.600000e+01
# mean         98.897222     1.097778  3.971861e+07
# std           0.506854     0.494791  5.050913e+07
# min          97.410000     0.030000  6.600100e+04
# ...

# %% [markdown]
#         b) using isnull() check for missing values in the data

# %%
ab.isnull().head()
# Out:
#    State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio
# 0      False        False   False       False   False         False  \
# 1      False        False   False       False   False         False
# 2      False        False   False       False   False         False
# 3      False        False   False       False   False         False
# 4      False        False   False       False   False         False
#
#    Discharge Ratio  Death Ratio  Population
# 0            False        False       False
# 1            False        False       False
# 2            False        False       False
# 3            False        False       False
# 4            False        False       False

# %%
print("Missing values in the dataset:")
ab.isnull().sum()
# Out:
# Missing values in the dataset:
# State/UTs          0
# Total Cases        0
# Active             0
# Discharged         0
# Deaths             0
# Active Ratio       0
# Discharge Ratio    0
# Death Ratio        0
# Population         0
# dtype: int64

# %% [markdown]
#         c) Dimensions of the data frame

# %%
ab.shape
# Out:
# (36, 9)

# %% [markdown]
#         d) variable description in dataset

# %%
ab.dtypes
# Out:
# State/UTs           object
# Total Cases          int64
# Active               int64
# Discharged           int64
# Deaths               int64
# Active Ratio       float64
# Discharge Ratio    float64
# Death Ratio        float64
# Population           int64
# dtype: object

# %%
ab.Active.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### 6. Turn categorical variables into quantitative variables in Python

# %%
cd=pd.read_csv('StatewiseTestingDetails.csv')
cd
# Out:
#              Date                        State  TotalSamples Negative
# 0      2020-04-17  Andaman and Nicobar Islands        1403.0     1210  \
# 1      2020-04-24  Andaman and Nicobar Islands        2679.0      NaN
# 2      2020-04-27  Andaman and Nicobar Islands        2848.0      NaN
# 3      2020-05-01  Andaman and Nicobar Islands        3754.0      NaN
# 4      2020-05-16  Andaman and Nicobar Islands        6677.0      NaN
# ...           ...                          ...           ...      ...
# 16331  2021-08-06                  West Bengal    15999961.0      NaN
# 16332  2021-08-07                  West Bengal    16045662.0      NaN
# 16333  2021-08-08                  West Bengal    16092192.0      NaN
# 16334  2021-08-09                  West Bengal    16122345.0      NaN
# 16335  2021-08-10                  West Bengal    16162814.0      NaN
#
#        Positive
# 0          12.0
# 1          27.0
# 2          33.0
# 3          33.0
# 4          33.0
# ...         ...
# ...

# %%
cd['State']
# Out:
# 0        Andaman and Nicobar Islands
# 1        Andaman and Nicobar Islands
# 2        Andaman and Nicobar Islands
# 3        Andaman and Nicobar Islands
# 4        Andaman and Nicobar Islands
#                     ...
# 16331                    West Bengal
# 16332                    West Bengal
# 16333                    West Bengal
# 16334                    West Bengal
# 16335                    West Bengal
# Name: State, Length: 16336, dtype: object

# %%
cd['State'] = cd['State'].astype('category').cat.codes
print(cd['State'])
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 16331    35
# 16332    35
# 16333    35
# 16334    35
# 16335    35
# Name: State, Length: 16336, dtype: int8

# %%
cd.shape
# Out:
# (16336, 5)
